# %%
import pandas as pd

# %%
import metplotlib as mt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Al hamad\OneDrive\Documents\netflix_titles.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df['release_year'].mean()
# Out:
# np.float64(2014.1801975701146)

# %%
df['release_year'].median()
# Out:
# 2017.0

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
#Cleaning of data 
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
import seaborn as sns
sns.countplot(x='type', data=df)
plt.title("Movies vs TV shows")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 import seaborn as sns
#       2 sns.countplot(x='type', data=df)
# ----> 3 plt.title("Movies vs TV shows")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
top_country = df['country'].value_counts().head(10)

top_country.plot(kind='bar')
plt.title("Top 10 Countries")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 top_country = df['country'].value_counts().head(10)
#       3 top_country.plot(kind='bar')
# ----> 4 plt.title("Top 10 Countries")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df['release_year'].value_counts().head(10)
# Out:
# release_year
# 2017    657
# 2018    648
# 2016    577
# 2019    519
# 2020    442
# 2015    349
# 2014    242
# 2013    197
# 2012    163
# 2021    161
# Name: count, dtype: int64

# %% [markdown]
# 1. Movies are more common than TV Shows.
# 2. United States has highest content count.
# 3. Most Netflix content released after 2015.
# 4. Some movies are unusually long (outliers).
# 5. Missing values were found in country and director columns.
